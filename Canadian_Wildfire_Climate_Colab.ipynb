# %% [markdown]
# # 🔥 Canadian Wildfire Analysis Lab
#
# **Objective**: Analyze Canada's burned area trends using the National Burned Area Composite (NBAC) and climate temperature anomalies.
#
# We will merge and visualize these datasets to explore the connection between wildfires and climate change.

# %%
# 📦 Step 1: Install Required Packages
# %pip install pandas matplotlib seaborn requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 📂 Step 2: Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %% [markdown]
# ## 🔗 Step 3: Load the Datasets
#
# **Note**: Replace these URLs with working CSVs from Government of Canada and temperature anomaly datasets.

# %%
# Placeholder NBAC data: burned area by year (replace with actual file/URL)
# nbac_url = 'https://raw.githubusercontent.com/adamkashtanov/data/main/nbac_burned_area.csv'
# If the URL is not working, create a placeholder DataFrame
nbac = pd.DataFrame({
	'Year': [2015, 2016, 2017, 2018, 2019, 2020],
	'Burned_Ha': [2500000, 1800000, 3200000, 2100000, 2700000, 1500000]
})
nbac.head()
# Out:
#    Year  Burned_Ha
# 0  2015    2500000
# 1  2016    1800000
# 2  2017    3200000
# 3  2018    2100000
# 4  2019    2700000

# %%
# Placeholder temperature anomaly data (Berkeley Earth or NASA GISTEMP)
temp_url = 'https://raw.githubusercontent.com/datasets/global-temp/master/data/annual.csv'
temp = pd.read_csv(temp_url)
temp = temp.rename(columns={"Mean": "Temp_Anomaly"})[['Year', 'Temp_Anomaly']]
temp.head()
# Out:
#    Year  Temp_Anomaly
# 0  1850       -0.4177
# 1  1851       -0.2333
# 2  1852       -0.2294
# 3  1853       -0.2704
# 4  1854       -0.2915

# %%
# Merge datasets
df = pd.merge(nbac, temp, on='Year', how='inner')
df.head()
# Out:
#    Year  Burned_Ha  Temp_Anomaly
# 0  2015    2500000        0.8975
# 1  2015    2500000        0.8251
# 2  2016    1800000        1.0133
# 3  2016    1800000        0.9329
# 4  2017    3200000        0.9200

# %% [markdown]
# ## 📈 Step 4: Visualizations

# %%
# Plot Burned Area by Year
plt.figure(figsize=(12,6))
sns.lineplot(data=df, x='Year', y='Burned_Ha', marker='o')
plt.title('Canadian Burned Area per Year (NBAC)')
plt.ylabel('Burned Area (hectares)')
plt.xlabel('Year')
plt.grid(True)
plt.show()

# %%
# Scatterplot: Temp Anomaly vs. Burned Area
plt.figure(figsize=(12,6))
sns.scatterplot(data=df, x='Temp_Anomaly', y='Burned_Ha')
plt.title('Burned Area vs. Temperature Anomaly')
plt.xlabel('Temperature Anomaly (°C)')
plt.ylabel('Burned Area (hectares)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 🧠 Step 5: Reflection Questions
# 1. What patterns do you see in the burned area over time?
# 2. How does burned area relate to temperature anomalies?
# 3. What factors might contribute to year-to-year variability beyond temperature (e.g., drought, wind, suppression policies)?
# 4. What are the implications for future fire management in Canada under continued warming?
#
# **Optional**: Add drought index data or Fire Weather Index (FWI) for deeper analysis.
